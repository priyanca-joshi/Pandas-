# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Youtube Data.csv')

# %%
df
# Out:
#      Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 0             0          India                                     28.1
# 1             2  United States                                     88.2
# 2             3  United States                                     88.2
# 3             4          India                                     28.1
# 4             8         Russia                                     81.9
# ..          ...            ...                                      ...
# 549         989  United States                                     88.2
# 550         990         Brazil                                     51.3
# 551         991          India                                     28.1
# 552         993         Sweden                                     67.0
# 553         994          India                                     28.1
#
#      Population                       Title  Unemployment rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               554 non-null    int64
#  1   Country                                  554 non-null    object
#  2   Gross tertiary education enrollment (%)  554 non-null    float64
#  3   Population                               554 non-null    int64
#  4   Title                                    554 non-null    object
#  5   Unemployment rate                        554 non-null    float64
#  6   Urban_population                         554 non-null    int64
#  7   Youtuber                                 554 non-null    object
#  8   category                                 554 non-null    object
#  9   channel_type                             554 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Gross tertiary education enrollment (%)    Population  \
# count  554.000000                               554.000000  5.540000e+02
# mean   462.828520                                60.533574  4.965559e+08
# std    289.929893                                26.365440  5.178813e+08
# min      0.000000                                 7.600000  2.025060e+05
# 25%    205.500000                                28.100000  1.023202e+08
# 50%    447.500000                                60.000000  3.282395e+08
# 75%    701.750000                                88.200000  1.366418e+09
# max    994.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population  channel_type_rank  country_rank  \
# count         554.000000      5.540000e+02         554.000000    554.000000
# mean            8.866029      2.402031e+08         238.034296    180.850181
# std             4.813768      1.641213e+08         937.109139    732.093496
# ...

# %%
df.shape
# Out:
# (554, 28)

# %% [markdown]
# Case Study 1 : Analyzing YouTube Growth Trends Across Countries
# Background:
#
# You’re a data analyst working for a global media company studying the influence of education and urbanization on YouTube content creation.
#
# The company wants to understand how different countries perform based on certain socio-economic factors and YouTube metrics.
#
# 🧠 Questions:
#
# Reading & Boolean Indexing
# Filter and display all YouTubers from India whose Unemployment rate is below 6% and who have more than 5 million subscribers.
# Indexing & Slicing + Unique
# List the first 5 YouTubers (rows) using slicing.
#
# Then, print the unique channel types in the dataset.
#
# Value_counts + Boolean Indexing
# Identify the top 3 most common categories on YouTube.
#
# Then, count how many YouTubers belong to the 'Entertainment' category.

# %%
df.head()
# Out:
#    Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 0           0          India                                     28.1
# 1           2  United States                                     88.2
# 2           3  United States                                     88.2
# 3           4          India                                     28.1
# 4           8         Russia                                     81.9
#
#    Population                       Title  Unemployment rate  \
# 0  1366417754                    T-Series               5.36
# 1   328239523                     MrBeast              14.70
# 2   328239523  Cocomelon - Nursery Rhymes              14.70
# 3  1366417754                   SET India               5.36
# 4   144373535            Like Nastya Vlog               4.59
#
#    Urban_population                    Youtuber        category  \
# 0         471031528                    T-Series           Music
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Gross tertiary education enrollment (%)',
#        'Population', 'Title', 'Unemployment rate', 'Urban_population',
#        'Youtuber', 'category', 'channel_type', 'channel_type_rank',
#        'country_rank', 'created_date', 'created_month', 'created_year',
#        'highest_monthly_earnings', 'highest_yearly_earnings',
#        'lowest_monthly_earnings', 'lowest_yearly_earnings', 'rank',
#        'subscribers', 'subscribers_for_last_30_days', 'uploads', 'video views',
#        'video_views_for_the_last_30_days', 'video_views_rank',
#        'engagement_rate', 'views_per_upload'],
#       dtype='object')

# %%
df['Unemployment rate'].describe()
# Out:
# count    554.000000
# mean       8.866029
# std        4.813768
# min        0.750000
# 25%        5.360000
# 50%        5.560000
# 75%       14.700000
# max       14.720000
# Name: Unemployment rate, dtype: float64

# %% [markdown]
# # Reading & Boolean Indexing
# # Filter and display all YouTubers from India
# # whose Unemployment rate is below 6% and who have more than 5 million subscribers.

# %%
cond = (df['Country']== 'India') & (df['Unemployment rate']<6) & (df['subscribers']> 5000000)
df[cond]
# Out:
#      Unnamed: 0 Country  Gross tertiary education enrollment (%)  Population  \
# 0             0   India                                     28.1  1366417754
# 3             4   India                                     28.1  1366417754
# 6            10   India                                     28.1  1366417754
# 9            15   India                                     28.1  1366417754
# 13           21   India                                     28.1  1366417754
# ..          ...     ...                                      ...         ...
# 541         964   India                                     28.1  1366417754
# 546         980   India                                     28.1  1366417754
# 547         984   India                                     28.1  1366417754
# 551         991   India                                     28.1  1366417754
# 553         994   India                                     28.1  1366417754
#
# ...

# %%
# Indexing & Slicing + Unique
# List the first 5 YouTubers (rows) using slicing.

# Then, print the unique channel types in the dataset.

# %%
df.loc[0:4,['Youtuber']]
# Out:
#                      Youtuber
# 0                    T-Series
# 1                     MrBeast
# 2  Cocomelon - Nursery Rhymes
# 3                   SET India
# 4                 Like Nastya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               554 non-null    int64
#  1   Country                                  554 non-null    object
#  2   Gross tertiary education enrollment (%)  554 non-null    float64
#  3   Population                               554 non-null    int64
#  4   Title                                    554 non-null    object
#  5   Unemployment rate                        554 non-null    float64
#  6   Urban_population                         554 non-null    int64
#  7   Youtuber                                 554 non-null    object
#  8   category                                 554 non-null    object
#  9   channel_type                             554 non-null    object
# ...

# %%
df.loc[:,'channel_type'].unique()
# Out:
# array(['Music', 'Entertainment', 'Education', 'People', 'Sports', 'Film',
#        'News', 'Games', 'Howto', 'Comedy', 'Nonprofit', 'Tech', 'Animals',
#        'Autos'], dtype=object)

# %%
# How many unique channel types are there in data?
df.loc[:,'channel_type'].unique().size
# Out:
# 14

# %%
# Value_counts + Boolean Indexing
# Identify the top 3 most common categories on YouTube.

# Then, count how many YouTubers belong to the 'Entertainment' category.

# %%
df.head(3)
# Out:
#    Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 0           0          India                                     28.1
# 1           2  United States                                     88.2
# 2           3  United States                                     88.2
#
#    Population                       Title  Unemployment rate  \
# 0  1366417754                    T-Series               5.36
# 1   328239523                     MrBeast              14.70
# 2   328239523  Cocomelon - Nursery Rhymes              14.70
#
#    Urban_population                    Youtuber       category   channel_type  \
# 0         471031528                    T-Series          Music          Music
# 1         270663028                     MrBeast  Entertainment  Entertainment
# 2         270663028  Cocomelon - Nursery Rhymes      Education      Education
#
#    ...  lowest_yearly_earnings  rank  subscribers  \
# 0  ...                 6800000     1    245000000
# ...

# %%
df2=df.loc[:,'category'].value_counts().head(3)
df2.reset_index()
#Top 3 common categories
# Out:
#          category  count
# 0   Entertainment    145
# 1           Music    110
# 2  People & Blogs     72

# %% [markdown]
# # Then, count how many YouTubers belong to the 'Entertainment' category.

# %%
df1=df[df.loc[:, 'category']== 'Entertainment']
df1
# Out:
#      Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 1             2  United States                                     88.2
# 5             9  United States                                     88.2
# 13           21          India                                     28.1
# 26           36  United States                                     88.2
# 35           46         Russia                                     81.9
# ..          ...            ...                                      ...
# 530         937  United States                                     88.2
# 537         960          India                                     28.1
# 539         962          India                                     28.1
# 540         963          India                                     28.1
# 541         964          India                                     28.1
#
#      Population                       Title  Unemployment rate  \
# ...

# %%
df1.loc[:,'Youtuber'].size
# Out:
# 145

# %% [markdown]
# Case Study 2: Cleaning & Organizing YouTube Earnings Data
# Background: As a senior data engineer, you're responsible for cleaning and organizing the data so it’s ready for executive reporting. The management is particularly interested in sorting earnings, updating column names, and resetting index formats.
#
# 🧠 Questions:
#
# Sort + Reset Index
# Sort the data in descending order of highest_yearly_earnings, and reset the index after sorting.
#
# Display the top 5 entries post-sort.
#
# Rename + Replace
# Rename the column highest_monthly_earnings to max_monthly_income and lowest_monthly_earnings to min_monthly_income.
#
# Replace all occurrences of the Category Column - "People & Blogs" with "Personal Vlogs".
#
# Set Index + Reset Index
# Set Youtuber as the new index and display the data.
#
# Then reset the index to bring it back to default.

# %%
df.head()
# Out:
#    Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 0           0          India                                     28.1
# 1           2  United States                                     88.2
# 2           3  United States                                     88.2
# 3           4          India                                     28.1
# 4           8         Russia                                     81.9
#
#    Population                       Title  Unemployment rate  \
# 0  1366417754                    T-Series               5.36
# 1   328239523                     MrBeast              14.70
# 2   328239523  Cocomelon - Nursery Rhymes              14.70
# 3  1366417754                   SET India               5.36
# 4   144373535            Like Nastya Vlog               4.59
#
#    Urban_population                    Youtuber        category  \
# 0         471031528                    T-Series           Music
# ...

# %% [markdown]
# Sort + Reset Index Sort the data in descending order of highest_yearly_earnings, and reset the index after sorting.
#
# Display the top 5 entries post-sort.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               554 non-null    int64
#  1   Country                                  554 non-null    object
#  2   Gross tertiary education enrollment (%)  554 non-null    float64
#  3   Population                               554 non-null    int64
#  4   Title                                    554 non-null    object
#  5   Unemployment rate                        554 non-null    float64
#  6   Urban_population                         554 non-null    int64
#  7   Youtuber                                 554 non-null    object
#  8   category                                 554 non-null    object
#  9   channel_type                             554 non-null    object
# ...

# %%
# Sort the data in descending order of
# highest_yearly_earnings, and reset the index after sorting.
df.sort_values(by = 'highest_yearly_earnings', ascending=False, inplace=True)
# without inplace = True --> original data will not change | only changed data will be displayed
# with inplace = True --> original data is changed

# %%
df.head().ignore_index=True
df.head().reset_index(drop=True)
# Top 5 entries
# Out:
#    Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 0         417  United States                                     88.2
# 1           0          India                                     28.1
# 2           3  United States                                     88.2
# 3           4          India                                     28.1
# 4          21          India                                     28.1
#
#    Population                       Title  Unemployment rate  \
# 0   328239523                DaFuq!?Boom!              14.70
# 1  1366417754                    T-Series               5.36
# 2   328239523  Cocomelon - Nursery Rhymes              14.70
# 3  1366417754                   SET India               5.36
# 4  1366417754                      Zee TV               5.36
#
#    Urban_population                    Youtuber          category  \
# 0         270663028                DaFuq!?Boom!  Film & Animation
# ...

# %% [markdown]
# Rename + Replace Rename the column highest_monthly_earnings to max_monthly_income and lowest_monthly_earnings to min_monthly_income.

# %%
df.rename(columns = {'highest_monthly_earnings': 'max_monthly_income','lowest_monthly_earnings': 'min_monthly_income'}, inplace=True)
df
# Out:
#      Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 261         417  United States                                     88.2
# 0             0          India                                     28.1
# 2             3  United States                                     88.2
# 3             4          India                                     28.1
# 13           21          India                                     28.1
# ..          ...            ...                                      ...
# 120         175  United States                                     88.2
# 491         859  United States                                     88.2
# 74           99          India                                     28.1
# 282         455         Brazil                                     51.3
# 514         902      Indonesia                                     36.3
#
#      Population                       Title  Unemployment rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 554 entries, 261 to 514
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               554 non-null    int64
#  1   Country                                  554 non-null    object
#  2   Gross tertiary education enrollment (%)  554 non-null    float64
#  3   Population                               554 non-null    int64
#  4   Title                                    554 non-null    object
#  5   Unemployment rate                        554 non-null    float64
#  6   Urban_population                         554 non-null    int64
#  7   Youtuber                                 554 non-null    object
#  8   category                                 554 non-null    object
#  9   channel_type                             554 non-null    object
# ...

# %% [markdown]
# Replace all occurrences of the Category Column - "People & Blogs" with "Personal Vlogs".

# %%
df['category'].replace({'People & Blogs' : 'Personal Vlogs'}, inplace=True)
df
# Out:
#      Unnamed: 0        Country  Gross tertiary education enrollment (%)  \
# 261         417  United States                                     88.2
# 0             0          India                                     28.1
# 2             3  United States                                     88.2
# 3             4          India                                     28.1
# 13           21          India                                     28.1
# ..          ...            ...                                      ...
# 120         175  United States                                     88.2
# 491         859  United States                                     88.2
# 74           99          India                                     28.1
# 282         455         Brazil                                     51.3
# 514         902      Indonesia                                     36.3
#
#      Population                       Title  Unemployment rate  \
# ...

# %%
df['category'].unique()
# Out:
# array(['Film & Animation', 'Music', 'Education', 'Shows', 'Entertainment',
#        'Personal Vlogs', 'Comedy', 'Gaming', 'Pets & Animals', 'Sports',
#        'News & Politics', 'Autos & Vehicles', 'Movies', 'Howto & Style',
#        'Trailers', 'Science & Technology', 'Nonprofits & Activism'],
#       dtype=object)

# %% [markdown]
# Set Index + Reset Index Set Youtuber as the new index and display the data.
#
# Then reset the index to bring it back to default.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 554 entries, DaFuq!?Boom! to Calon Sarjana
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               554 non-null    int64
#  1   Country                                  554 non-null    object
#  2   Gross tertiary education enrollment (%)  554 non-null    float64
#  3   Population                               554 non-null    int64
#  4   Title                                    554 non-null    object
#  5   Unemployment rate                        554 non-null    float64
#  6   Urban_population                         554 non-null    int64
#  7   category                                 554 non-null    object
#  8   channel_type                             554 non-null    object
#  9   channel_type_rank                        554 non-null    int64
# ...

# %%
df.set_index('Youtuber', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-1759482937> in <cell line: 0>()
# ----> 1 df.set_index('Youtuber', inplace = True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Youtuber'] are in the columns"

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      subscribers  Unnamed: 0        Country  \
# 0       19600000         417  United States
# 1      245000000           0          India
# 2      162000000           3  United States
# 3      159000000           4          India
# 4       70500000          21          India
# ..           ...         ...            ...
# 549     29200000         175  United States
# 550     13400000         859  United States
# 551     36600000          99          India
# 552     18500000         455         Brazil
# 553     13000000         902      Indonesia
#
#      Gross tertiary education enrollment (%)  Population  \
# 0                                       88.2   328239523
# 1                                       28.1  1366417754
# 2                                       88.2   328239523
# 3                                       28.1  1366417754
# 4                                       28.1  1366417754
# ..                                       ...         ...
# ...
